# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
Inpu_nms = {"DEPTH", "TRANY", "PORV", "TRANX", "PERMZ", "TRANZ", "PORO", "SATNUM", "PERMY", "PERMX"}
data = {}

def np_load(input_nm, file_nm, rp):
    try:
        d = np.load(rp, allow_pickle=True)
        return d  # Always load data
    except ValueError as e:
        print(input_nm, file_nm, e)
        raise e

for root, dirs, files in os.walk("./origen_interview_data/", topdown=False):
    root_parts = root.split("/")
    assert len(root_parts) == 3, "too many parts in %s" % root
    input_name = root_parts[-1]
    
    # Process only if the input_name is in the specified set
    if input_name in Inpu_nms:
        for file in filter(".DS_Store".__ne__, files):
            file_parts = file.split(".")
            assert len(file_parts) == 2, "unexpected filename pattern: %s" % file
            dataset_name = file_parts[0]
            realpath = os.path.realpath(os.path.join(root, file))
            # Load data and store it in the dictionary
            data[input_name, dataset_name] = np_load(input_name, file, realpath)

# %%
target_data = {}
target_names = {"BHP", "WOPR"}

def np_load(input_nm, file_nm, rp):
    try:
        d = np.load(rp, allow_pickle=True)
        if input_nm in target_names:  # Save data only for specified input_nm
            if input_nm in target_names:
                # d = d.reshape(15, 25, 24)
                return d
    except ValueError as e:
        print(input_nm, file_nm, e)
        raise e

for root, dirs, files in os.walk("./origen_interview_data/", topdown=False):
    root_parts = root.split("/")
    assert len(root_parts) == 3, "too many parts in %s" % root
    input_name = root_parts[-1]
    
    # Print "processing input" only for specified input_nm
    if input_name in target_names:
        for file in filter(".DS_Store".__ne__, files):
            file_parts = file.split(".")
            assert len(file_parts) == 2, "unexpected filename pattern: %s" % file
            dataset_name = file_parts[0]
            realpath = os.path.realpath(os.path.join(root, file))
            # Print "loading" only for specified input_nm
            # print("loading %s file %s" % (input_name, dataset_name))
            target_data[input_name, dataset_name] = np_load(input_name, file, realpath)

# %%
# X = []
# y = []

# for key, value in data.items():
#     input_data, _ = key
#     X.append(value)  # Flatten the input data

# for key, value in target_data.items():
#     taget_data, _ = key
#     y.append(value)

# %%
# for k, v in target_data.items():
#     # print("key: %s, value: %s" % (k, v))
#     print(v.shape)
#     # print(k)

# %%
# import numpy as np

# # Create 1000 target variables with shape (300, 7)
# num_targets = 1000
# target_shape = (300, 7)
# target_keys = ["target_" + str(i) for i in range(num_targets)]  # Creating column names
# target_data = {key: np.random.rand(*target_shape) for key in target_data}

# # Create 6000 input variables with shape (15, 25, 24)
# num_inputs = 6000
# input_shape = (15, 25, 24)
# input_keys = ["input_" + str(i) for i in range(num_inputs)]  # Creating column names
# input_data = {key: np.random.rand(*input_shape) for key in data}

# # Append values to X and y lists
# X = [value for key, value in input_data.items()]
# y = [value for key, value in target_data.items()]

# # Print the shapes of the first target and input variables as examples
# print("Input shape:", X[0].shape)
# print("Target shape:", y[0].shape)

# %%
# X = np.array(X)

# %%
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras import layers, models

# # Assuming you have loaded your data into X (input) and y (target)
# # X should have shape (6000, 15, 25, 24)
# # y should have shape (1000, 300, 7)

# # Convert input data (X) and target data (y) to NumPy arrays
# X = np.array(X)
# y = np.array(y)

# # Reshape input data to include the depth dimension (1)
# X_train = np.array(X_train)
# X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2], X_train.shape[3], 1))

# # Split into train and eval sets
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=300, random_state=42)

# model = models.Sequential()
# model.add(layers.Conv3D(32, (3, 3, 3), activation='relu', input_shape=(15, 25, 24, 1), padding='same'))
# model.add(layers.MaxPooling3D((2, 2, 2)))
# model.add(layers.Conv3D(64, (3, 3, 3), activation='relu', padding='same'))
# model.add(layers.MaxPooling3D((2, 2, 2)))
# model.add(layers.Conv3D(128, (3, 3, 3), activation='relu', padding='same'))
# model.add(layers.Flatten())
# model.add(layers.Dense(300, activation='relu'))
# model.add(layers.Dense(300 * 7, activation='linear'))  # Adjust activation based on your problem

# # Reshape output to match target data shape
# model.add(layers.Reshape((300, 7)))

# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
# # Iterate through the data in chunks


# # Assuming you have split your data into training and validation sets
# # Adjust the split ratio as needed
# validation_split = 0.2
# split_index = int(len(X) * (1 - validation_split))

# X_train, X_val = X_reshaped[:split_index], X_reshaped[split_index:]
# y_train, y_val = y[:split_index], y[split_index:]

# # Ensure the shapes match
# assert X_val.shape[0] == y_val.shape[0], "Mismatch in the number of samples between X_val and y_val"

# # Convert to numpy arrays (if not already)
# X_val = np.array(X_val)
# y_val = np.array(y_val)

# # Evaluate the model on the validation set
# val_loss, val_mae = model.evaluate(X_val, y_val, verbose=0)

# # Print the validation loss and metric
# print(f"Validation Loss: {val_loss:.4f}, Validation MAE: {val_mae:.4f}")

# batch_size = 8  # Choose an appropriate batch size
# epochs = 10

# # Training loop
# for epoch in range(epochs):
#     print(f"Epoch {epoch + 1}/{epochs}")
#     for i in range(0, len(X_train), batch_size):
#         X_batch = X_train[i:i + batch_size]
#         y_batch = y_train[i:i + batch_size]

#         # Ensure both X_batch and y_batch have the same number of samples
#         assert X_batch.shape[0] == y_batch.shape[0], "Mismatch in the number of samples"

#         # Train the model on the current batch
#         model.train_on_batch(X_batch, y_batch)

#     # Evaluate the model on the validation set after each epoch
#     val_loss, val_mae = model.evaluate(X_val, y_val, verbose=0)
#     print(f"Validation Loss: {val_loss:.4f}, Validation MAE: {val_mae:.4f}")

# %%
# # split_index = int(len(X) * (1 - validation_split))

# # X_train, X_val = X[:split_index], X[split_index:]
# # y_train, y_val = y[:split_index], y[split_index:]

# X_train = np.array(X_train)
# X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2], X_train.shape[3], 1))

# # Split into train and eval sets
# X_train_split, X_eval, y_train_split, y_eval = train_test_split(X_train, y_train, test_size=300, random_state=42)

# # # Randomly choose 700 indices
# # selected_indices = np.random.choice(X_train.shape[0], 700, replace=False)
# # selected_indices_y = np.random.choice(y_train.shape[0], 700, replace=False)

# # # Select the corresponding samples
# # X_train = X_train[selected_indices]
# # y_train = y_train[selected_indices_y]

# # Verify the shape
# print("X_train_selected shape:", X_train_selected.shape)
# # Convert to numpy arrays (if not already)
# X_train = np.array(X_train)
# y_train = np.array(y_train)
# X_eval = np.array(X_eval)
# y_eval = np.array(y_eval)
# print("X_train shape:", X_train.shape)
# print("y_train shape:", y_train.shape)
# print("X_val shape:", X_val.shape)
# print("y_val shape:", y_val.shape)

# %%
Inpu_nms = {"DEPTH", "TRANY", "PORV", "TRANX", "PERMZ", "TRANZ", "PORO", "SATNUM", "PERMY", "PERMX"}
data = {}

def np_load(input_nm, file_nm, rp):
    try:
        d = np.load(rp, allow_pickle=True)
        return d  # Always load data
    except ValueError as e:
        print(input_nm, file_nm, e)
        raise e

for root, dirs, files in os.walk("./origen_interview_data/", topdown=False):
    root_parts = root.split("/")
    assert len(root_parts) == 3, "too many parts in %s" % root
    input_name = root_parts[-1]
    
    # Process only if the input_name is in the specified set
    if input_name in Inpu_nms:
        for file in filter(".DS_Store".__ne__, files):
            file_parts = file.split(".")
            assert len(file_parts) == 2, "unexpected filename pattern: %s" % file
            dataset_name = file_parts[0]
            realpath = os.path.realpath(os.path.join(root, file))
            # Load data and store it in the dictionary
            data[input_name, dataset_name] = np_load(input_name, file, realpath)

# %%
def read_df(input_nm: str):
    try:
        return pd.DataFrame({
            "%s_%s" % (input_nm.lower(), k.split("_")[0]): data[input_nm, k]  # Use flatten to convert 3D array to 1D
            for k in sorted(
                [k[1] for k in data.keys() if k[0] == input_nm],
                key=lambda x: int(x.split("_")[0][3:])
            )
        })
    except ValueError as e:
        print(input_nm, e)
        return None

# %%
dfs = {input_nm: read_df(input_nm) for input_nm in set([k[0] for k in data.keys()])}

# %%
dfs.keys()
# Out:
# dict_keys(['PORV', 'PORO', 'PERMX', 'DEPTH', 'PERMY', 'TRANZ', 'PERMZ', 'TRANY', 'SATNUM', 'TRANX'])

# %%
Inpu_nms =  dfs.keys()
df = pd.concat([
    pd.concat([
        pd.DataFrame({"name": [k, ] * v.shape[0]}, index=v.index),
        v.rename(columns={c: c.split("_")[-1] for c in v.columns}), 
    ], axis=1)
    for k, v in dfs.items() if k in Inpu_nms
])

df
# Out:
#        name          sim1           sim2          sim3           sim4  \
# 0      PORV  20205.417969  100770.289062  26725.011719  144922.781250
# 1      PORV  20833.140625  107188.578125  24851.781250  135372.609375
# 2      PORV  20220.164062  111583.593750  22467.527344  124643.945312
# 3      PORV  20209.585938  117093.320312  20373.408203  115084.796875
# 4      PORV  20251.904297  120891.390625  18629.699219  107206.851562
# ...     ...           ...            ...           ...            ...
# 8995  TRANX      1.246641       0.087491    383.646698       0.027402
# 8996  TRANX      1.657803       0.074622    324.912720       0.022145
# 8997  TRANX      1.966090       0.066380    276.617004       0.018484
# 8998  TRANX      1.948129       0.062885    244.764191       0.016237
# 8999  TRANX      0.000000       0.000000      0.000000       0.000000
#
#                sim5           sim6          sim7          sim8           sim9  \
# 0     112672.335938  102784.578125  26862.865234  20606.480469  142713.562500
# 1     111870.210938   95354.820312  24797.921875  18184.394531  141157.718750
# 2      20728.306641   89007.710938  22263.308594  16456.394531  135267.453125
# 3      20831.537109   83839.421875  18776.531250  15906.576172  130225.476562
# 4      19849.558594   79148.492188  16588.478516  15405.488281  124976.398438
# ...             ...            ...           ...           ...            ...
# 8995       0.579746       0.072957      0.216161      0.758826       0.083559
# 8996       0.439602       0.089111      0.284017      1.017655       0.066523
# 8997       0.330207       0.106321      0.387255      1.198233       0.048847
# 8998       0.274440       0.125396      0.514517      1.262442       0.034782
# 8999       0.000000       0.000000      0.000000      0.000000       0.000000
#
#       ...        sim491        sim492        sim493        sim494  \
# 0     ...  21299.923828  28847.662109  16654.201172  24843.447266
# 1     ...  21542.292969  31189.277344  15583.417969  25249.958984
# 2     ...  21339.998047  32704.404297  14193.002930  25086.777344
# 3     ...  21328.136719  33433.113281  13015.462891  23535.744141
# 4     ...  20312.816406  33345.269531  12082.855469  20327.242188
# ...   ...           ...           ...           ...           ...
# 8995  ...      0.039217      0.057043      0.357992      0.278791
# 8996  ...      0.044916      0.033937      0.233237      0.323357
# 8997  ...      0.056753      0.025167      0.156917      0.291023
# 8998  ...      0.087303      0.021359      0.109779      0.210010
# 8999  ...      0.000000      0.000000      0.000000      0.000000
#
#             sim495         sim496        sim497        sim498        sim499  \
# 0     14884.203125  126035.640625  31350.857422  15625.736328  16680.810547
# 1     15658.116211  129759.656250  31413.052734  14199.735352  15419.594727
# 2     16418.564453  132671.281250  30921.902344  14114.137695  15282.060547
# 3     16575.976562  136191.078125  30414.082031  14853.426758  15101.245117
# 4     16663.177734  138430.109375  29040.337891  15127.534180  16351.560547
# ...            ...            ...           ...           ...           ...
# 8995      0.072857      53.567741     75.371002      0.044864      0.702166
# 8996      0.061000      42.919964     80.794380      0.020347      0.586513
# 8997      0.057853      42.687954     89.421051      0.010143      0.478547
# 8998      0.068671      51.071224    102.775917      0.006522      0.353065
# 8999      0.000000       0.000000      0.000000      0.000000      0.000000
#
#             sim500
# 0     19980.361328
# 1     18286.664062
# 2     16369.513672
# 3     14990.640625
# 4     13746.416016
# ...            ...
# 8995      0.604817
# 8996      0.651515
# 8997      0.667799
# 8998      0.639232
# 8999      0.000000
#
# [90000 rows x 501 columns]

# %%
target_data = {}
target_names = {"BHP", "WOPR"}

def np_load(input_nm, file_nm, rp):
    try:
        d = np.load(rp, allow_pickle=True)
        if input_nm in target_names:  # Save data only for specified input_nm
            if input_nm in target_names:
                # d = d.reshape(15, 25, 24)
                return d
    except ValueError as e:
        print(input_nm, file_nm, e)
        raise e

for root, dirs, files in os.walk("./origen_interview_data/", topdown=False):
    root_parts = root.split("/")
    assert len(root_parts) == 3, "too many parts in %s" % root
    input_name = root_parts[-1]
    
    # Print "processing input" only for specified input_nm
    if input_name in target_names:
        for file in filter(".DS_Store".__ne__, files):
            file_parts = file.split(".")
            assert len(file_parts) == 2, "unexpected filename pattern: %s" % file
            dataset_name = file_parts[0]
            realpath = os.path.realpath(os.path.join(root, file))
            # Print "loading" only for specified input_nm
            # print("loading %s file %s" % (input_name, dataset_name))
            target_data[input_name, dataset_name] = np_load(input_name, file, realpath)

# %%
def read_df(input_nm: str):
    try:
        return pd.DataFrame({
            "%s_%s" % (input_nm.lower(), k.split("_")[0]): data[input_nm, k]
            for k in sorted(
                [k[1] for k in data.keys() if k[0] == input_nm],
                key=lambda x: int(x.split("_")[0][3:])
            )
        })
    except ValueError as e:
        print(input_nm, e)
        return None

dfs = {input_nm: read_df(input_nm) for input_nm in set([k[0] for k in data.keys()])}


df_result = pd.concat([df for df in dfs.values()], axis=0, ignore_index=True)

# %%
dfs = pd.concat([
    pd.concat([
        pd.DataFrame({"name": [k, ] * v.shape[0]}, index=v.index),
        v.rename(columns={c: c.split("_")[-1] for c in v.columns}), 
    ], axis=1)
    for k, v in dfs.items() if k in Inpu_nms
])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'name' column is categorical
label_encoder = LabelEncoder()
dfs['name_encoded'] = label_encoder.fit_transform(dfs['name']) +2

# %%
result = dfs[dfs['name_encoded'] == 11]
result
# Out:
#        name      sim1      sim2      sim3      sim4      sim5      sim6  \
# 0     TRANZ  0.159832  0.086487  0.335005  3.225324  0.099307  0.225116
# 1     TRANZ  0.180607  0.106126  0.226014  2.607353  0.154976  0.195621
# 2     TRANZ  0.160286  0.121656  0.147916  2.108963  0.098685  0.150983
# 3     TRANZ  0.159948  0.153261  0.098632  1.340142  0.116590  0.133282
# 4     TRANZ  0.161307  0.202869  0.072107  0.955459  0.111601  0.128162
# ...     ...       ...       ...       ...       ...       ...       ...
# 8995  TRANZ  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8996  TRANZ  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8997  TRANZ  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8998  TRANZ  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8999  TRANZ  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           sim7      sim8      sim9  ...    sim492    sim493    sim494  \
# 0     0.499588  0.127239  2.717454  ...  0.415256  0.047166  0.248216
# 1     0.362867  0.074434  2.279546  ...  0.572652  0.037736  0.266221
# 2     0.197894  0.051020  2.039845  ...  0.705658  0.028139  0.251221
# 3     0.104628  0.044811  1.533976  ...  0.802274  0.021011  0.196061
# 4     0.063994  0.041532  1.265849  ...  0.833570  0.016626  0.114150
# ...        ...       ...       ...  ...       ...       ...       ...
# 8995  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 8996  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 8997  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 8998  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 8999  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
#         sim495      sim496    sim497    sim498    sim499    sim500  \
# 0     0.047121    0.653350  0.926199  0.009395  0.074297  0.152744
# 1     0.057708    0.821803  0.933647  0.005685  0.054261  0.107245
# 2     0.069766    1.079077  0.655371  0.004328  0.052345  0.068897
# 3     0.064618    1.508131  0.629457  0.003973  0.049913  0.048465
# 4     0.065699  215.998276  0.538419  0.004439  0.068601  0.034277
# ...        ...         ...       ...       ...       ...       ...
# 8995  0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 8996  0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 8997  0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 8998  0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
# 8999  0.000000    0.000000  0.000000  0.000000  0.000000  0.000000
#
#       name_encoded
# 0               11
# 1               11
# 2               11
# 3               11
# 4               11
# ...            ...
# 8995            11
# 8996            11
# 8997            11
# 8998            11
# 8999            11
#
# [9000 rows x 502 columns]

# %%
target_data = {}
target_names = {"BHP", "WOPR"}

def np_load(input_nm, file_nm, rp):
    try:
        d = np.load(rp, allow_pickle=True)
        if input_nm in target_names:  # Save data only for specified input_nm
            if input_nm in target_names:
                # d = d.reshape(15, 25, 24)
                return d
    except ValueError as e:
        print(input_nm, file_nm, e)
        raise e

for root, dirs, files in os.walk("./origen_interview_data/", topdown=False):
    root_parts = root.split("/")
    assert len(root_parts) == 3, "too many parts in %s" % root
    input_name = root_parts[-1]
    
    # Print "processing input" only for specified input_nm
    if input_name in target_names:
        for file in filter(".DS_Store".__ne__, files):
            file_parts = file.split(".")
            assert len(file_parts) == 2, "unexpected filename pattern: %s" % file
            dataset_name = file_parts[0]
            realpath = os.path.realpath(os.path.join(root, file))
            # Print "loading" only for specified input_nm
            # print("loading %s file %s" % (input_name, dataset_name))
            target_data[input_name, dataset_name] = np_load(input_name, file, realpath)


df_BHP = pd.DataFrame({
            "%s_%s" % ("BHP".lower(), k.split("_")[0]): target_data["BHP", k].flatten()
            for k in sorted(
                [k[1] for k in target_data.keys() if k[0] == "BHP"],
                key=lambda x: int(x.split("_")[0][3:])
            )
        })

df_WOPR = pd.DataFrame({
            "%s_%s" % ("WOPR".lower(), k.split("_")[0]): target_data["WOPR", k].flatten()
            for k in sorted(
                [k[1] for k in target_data.keys() if k[0] == "WOPR"],
                key=lambda x: int(x.split("_")[0][3:])
            )
        })


target_df = pd.concat([
    pd.concat([
        pd.DataFrame({"name": [k, ] * v.shape[0]}, index=v.index),
        v.rename(columns={c: c.split("_")[-1] for c in v.columns}), 
    ], axis=1)
    for k, v in {"WOPR": df_WOPR, "BHP": df_BHP}.items()
])


target_df.head()
# Out:
#    name         sim1         sim2         sim3          sim4          sim5  \
# 0  WOPR  6759.295410    12.883436    69.527580     46.541042  15487.532227
# 1  WOPR  7369.289062    16.775690    38.210709     47.645752  14446.088867
# 2  WOPR  1078.612915    49.481422  4840.847656   4517.430176     19.930784
# 3  WOPR  1271.152954  6392.942871  6546.472656  12025.442383     11.913373
# 4  WOPR   798.250732  6898.095215  5763.392578   6471.474121     15.340807
#
#           sim6          sim7         sim8          sim9  ...        sim491  \
# 0  6104.012207    290.898193    44.279259    394.626221  ...     45.652409
# 1  6451.589844  14880.507812    67.406883  28994.697266  ...  10521.727539
# 2  4721.676270     63.181984  6449.222656    138.893036  ...   8899.494141
# 3  4091.390137     82.429085  6786.254883    178.071655  ...  10392.467773
# 4  3196.349854     43.487560  7975.293945     90.637207  ...     29.509521
#
#          sim492        sim493       sim494       sim495        sim496  \
# 0  19519.556641  13288.245117    41.505672    28.614569  11175.289062
# 1  10443.629883  12160.746094  5196.479492  1779.780640   4199.051758
# 2     10.858018    249.643661  4683.140137  1914.759644   2102.165039
# 3      7.390196    216.625717  4951.584473  3033.915527   2662.898438
# 4      3.047495    389.180176    27.644691  2718.701904   2162.393555
#
#          sim497      sim498       sim499       sim500
# 0  10932.378906   23.241556  3651.836670  2696.564697
# 1   8178.667480   15.453062  7140.892578  4355.360352
# 2   5666.400879   41.717621  3721.298584  8634.990234
# 3   4993.786621   33.037434  4600.001465  7435.370605
# 4    147.646408  128.067841  3005.179688   118.117302
#
# [5 rows x 501 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
target_df['name_encoded'] = label_encoder.fit_transform(target_df['name'])

# %%
dfs_encoded = dfs.drop(columns=['name'])
target_dfs_encoded = target_df.drop(columns=['name'])

# %%
target_dfs_encoded
# Out:
#              sim1         sim2         sim3          sim4          sim5  \
# 0     6759.295410    12.883436    69.527580     46.541042  15487.532227
# 1     7369.289062    16.775690    38.210709     47.645752  14446.088867
# 2     1078.612915    49.481422  4840.847656   4517.430176     19.930784
# 3     1271.152954  6392.942871  6546.472656  12025.442383     11.913373
# 4      798.250732  6898.095215  5763.392578   6471.474121     15.340807
# ...           ...          ...          ...           ...           ...
# 2095   400.000000  1111.188110   400.000000    671.752869    400.000000
# 2096   400.000000   947.010803   400.000000    626.972717    400.000000
# 2097   400.000000   994.219299   400.000000    728.786987    400.000000
# 2098   400.000000   957.362122   400.000000    684.335510    400.000000
# 2099   400.000000   963.475281   400.000000    647.340637    400.000000
#
#              sim6          sim7         sim8          sim9        sim10  ...  \
# 0     6104.012207    290.898193    44.279259    394.626221  1343.937988  ...
# 1     6451.589844  14880.507812    67.406883  28994.697266  2586.576904  ...
# 2     4721.676270     63.181984  6449.222656    138.893036  2843.940186  ...
# 3     4091.390137     82.429085  6786.254883    178.071655  4784.214844  ...
# 4     3196.349854     43.487560  7975.293945     90.637207  5118.585938  ...
# ...           ...           ...          ...           ...          ...  ...
# 2095  1078.145264    400.000000   400.000000    400.000000  1053.112427  ...
# 2096  1100.261108    400.000000   400.000000    400.000000  1052.021118  ...
# 2097  1270.876709    400.000000   400.000000    400.000000  1070.278442  ...
# 2098  1217.312012    400.000000   400.000000    400.000000  1024.680664  ...
# 2099  1301.798828    400.000000   400.000000    400.000000  1055.230469  ...
#
#             sim492        sim493       sim494       sim495        sim496  \
# 0     19519.556641  13288.245117    41.505672    28.614569  11175.289062
# 1     10443.629883  12160.746094  5196.479492  1779.780640   4199.051758
# 2        10.858018    249.643661  4683.140137  1914.759644   2102.165039
# 3         7.390196    216.625717  4951.584473  3033.915527   2662.898438
# 4         3.047495    389.180176    27.644691  2718.701904   2162.393555
# ...            ...           ...          ...          ...           ...
# 2095    400.000000    400.000000   400.000000  1597.291260   1260.779907
# 2096    400.000000    400.000000   400.000000  1589.765015   1273.591431
# 2097    400.000000    400.000000   400.000000  1644.383057   1335.386719
# 2098    400.000000    400.000000   400.000000  1578.907104   1255.956299
# 2099    400.000000    400.000000   400.000000  1584.662476   1315.279541
#
#             sim497      sim498       sim499       sim500  name_encoded
# 0     10932.378906   23.241556  3651.836670  2696.564697             1
# 1      8178.667480   15.453062  7140.892578  4355.360352             1
# 2      5666.400879   41.717621  3721.298584  8634.990234             1
# 3      4993.786621   33.037434  4600.001465  7435.370605             1
# 4       147.646408  128.067841  3005.179688   118.117302             1
# ...            ...         ...          ...          ...           ...
# 2095    400.000000  400.000000   400.000000   400.000000             0
# 2096    400.000000  400.000000   400.000000   400.000000             0
# 2097    400.000000  400.000000   400.000000   400.000000             0
# 2098    400.000000  400.000000   400.000000   400.000000             0
# 2099    400.000000  400.000000   400.000000   400.000000             0
#
# [4200 rows x 501 columns]

# %%
df_t = dfs_encoded.transpose()  
print(df_t.shape)
target_df_t = target_dfs_encoded.transpose()
target_df_t.shape
# Out:
# (501, 90000)
# (501, 4200)

# %%
from absl import flags
from datetime import datetime
import numpy as np
import random
from os.path import join as pjoin
import torch
import tensorflow as tf
from tensorflow.keras.layers import GaussianNoise, LSTM, Dropout, Dense
from tensorflow.keras.layers import Flatten

flags.DEFINE_string('TARGET_WELL', default='default_value', help='Description of TARGET_WELL')
flags.DEFINE_integer('EPOCHS', default=10, help='Number of training epochs')
flags.DEFINE_integer('BATCH_SIZE', default=32, help='Batch size for training')

# Mark the flags as parsed to prevent duplicate definition error
FLAGS = flags.FLAGS
FLAGS.mark_as_parsed()


def _get_log_path():
    return pjoin("logs", f"well_{FLAGS.TARGET_WELL}")

def main(argv=None):
    random.seed(7)
    
    
    
    def get_model(params):
        input_shape = params["input_shape"]
        lstm1_units = params["lstm1_units"]
        lstm2_units = params["lstm2_units"]
        gaussian_std = params["gaussian_std"]
        dropout_rate = params["dropout_rate"]
        optimizer = params["optimizer"]
        loss = params["loss"]
    
        model = tf.keras.models.Sequential()
        model.add(GaussianNoise(gaussian_std, input_shape=input_shape))
    
        model.add(LSTM(lstm1_units, activation='relu', return_sequences=True))
        model.add(Dropout(dropout_rate))
    
        model.add(LSTM(lstm2_units, activation='relu', return_sequences=True))
        model.add(Dropout(dropout_rate))
        model.add(Flatten())
    
        # Equivalent to nn.Linear(90000, 256)
        model.add(Dense(256, activation='relu'))
    
        # Equivalent to nn.Linear(256, 4200)
        model.add(Dense(4200, activation='linear'))
    
        model.compile(optimizer=optimizer, loss=loss)
    
        model.summary()
    
        return model

    
    # Specify the indices for training, testing, and validation
    train_indices = range(0, 450)
    test_indices = range(450, 475)
    val_indices = range(475, 500)
    
    df_input = df_t
    df_targets = target_df_t
    # processor.remove_zero_wopr(well)

    # Convert DataFrames to PyTorch tensors
    input_data = torch.tensor(df_input.values, dtype=torch.float32)
    targets = torch.tensor(df_targets.values, dtype=torch.float32)
    
    # Split the data into training, testing, and validation sets
    input_train, targets_train = input_data[train_indices], targets[train_indices]
    input_test, targets_test = input_data[test_indices], targets[test_indices]
    input_val, targets_val = input_data[val_indices], targets[val_indices]

    
    # Convert NumPy arrays to PyTorch tensors
    train_x = torch.tensor(input_train, dtype=torch.float32)
    train_y = torch.tensor(targets_train, dtype=torch.float32)
    val_x = torch.tensor(input_val, dtype=torch.float32)
    test_x = torch.tensor(input_test, dtype=torch.float32)

    train_y = torch.tensor(targets_train, dtype=torch.float32)
    val_y = torch.tensor(targets_val, dtype=torch.float32)
    test_y = torch.tensor(targets_test, dtype=torch.float32)


    
    print("Shapes before calling get_model:")
    print("train_x shape:", train_x.shape)
    print("train_y shape:", train_y.shape)
    
    train_data = torch.utils.data.TensorDataset(train_x, train_y)
    train_loader = torch.utils.data.DataLoader(train_data, batch_size=FLAGS.BATCH_SIZE, shuffle=True)

    val_data = torch.utils.data.TensorDataset(val_x, val_y)
    val_loader = torch.utils.data.DataLoader(val_data, batch_size=FLAGS.BATCH_SIZE, shuffle=False)

    # Convert PyTorch tensors to NumPy arrays
    train_x_numpy = train_x.numpy()
    train_y_numpy = train_y.numpy()
    val_x_numpy = val_x.numpy()
    val_y_numpy = val_y.numpy()

    lstm_model = get_model(params={
        "input_shape": (train_x_numpy.shape[1], 1),  # Assuming each feature corresponds to a time step
        "lstm1_units": 50,
        "lstm2_units": 50,
        "gaussian_std": 0.1,
        "dropout_rate": 0.2,
        "optimizer": "adam",
        "loss": "mean_squared_error"
    })

    latest = tf.train.latest_checkpoint(_get_log_path())
    print(f"latest checkpoint: {latest}")
    if latest is not None:
        print("Restoring trained weights")
        lstm_model.load_weights(latest)
    else:
        for epoch in range(FLAGS.EPOCHS):
            for batch_x, batch_y in train_loader:
                # Convert PyTorch tensors to NumPy arrays for each batch
                batch_x_numpy = batch_x.numpy()
                batch_y_numpy = batch_y.numpy()

                print("Batch X shape:", batch_x.shape)
                print("Batch Y shape:", batch_y.shape)
                # Train the model on the current batch
                history = lstm_model.train_on_batch(batch_x_numpy, batch_y_numpy)


    es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=6, verbose=1)
    timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
    logdir = pjoin(_get_log_path(), 'scalars')
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
    checkpoint_path = pjoin(_get_log_path(), "model.ckpt-{epoch:04d}")
    checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, verbose=1)

    latest = tf.train.latest_checkpoint(_get_log_path())
    print(f"latest checkpoint: {latest}")
    if latest is not None:
        print("Restoring trained weights")
        lstm_model.load_weights(latest)
    else:
        history = lstm_model.fit(
            train_loader,
            epochs=FLAGS.EPOCHS,
            validation_data=val_loader,
            use_multiprocessing=True,
            workers=8,
            callbacks=[es, tensorboard_callback]
        )
        print("training has been ended")

        lstm_model.save_weights(checkpoint_path.format(epoch=FLAGS.EPOCHS))
        print("model weights are saved")
        np.save(pjoin(_get_result_path(), f"ground_truth_{timestamp}.npy"), test_y.numpy())
        print("Ground Truth is saved...")
    def cascade_inference(model, test_x, test_y, obs, gaussian_std):
        y_hat_list = []
        observed = test_y[:obs]
        y_hat_list.extend(observed)
    
        buffer = test_x[obs:obs+1]
        mu = gaussian_std
    
        for i in range(obs+1, test_x.shape[0]):
            y_hat = model.predict(buffer)
            predicted_val = y_hat[0, 0, 0]
            y_hat_list.append(predicted_val)
        
            buffer = np.delete(buffer, 0, 1)
            next_wbhp = test_x[i:i+1][0, 4, 1]
            predicted_array = np.array([[predicted_val, next_wbhp]])
        
            buffer = np.vstack((buffer[0], predicted_array))
            buffer = np.reshape(buffer, (1, 5, 2))
        
            mean_wopr = np.mean(buffer[0], axis=0)[0]
            mean_wbhp = np.mean(buffer[0], axis=0)[1]
            wopr_predicted_noise_added = np.random.normal(mean_wopr, mu, 1)
            wbhp_predicted_noise_added = np.random.normal(mean_wbhp, mu, 1)
        
            buffer[0, 4, 0] = wopr_predicted_noise_added
            buffer[0, 4, 1] = wbhp_predicted_noise_added
    
        return y_hat_list
    ## Inference
    y_hat_list = cascade_inference(
        lstm_model,
        test_x.numpy(),
        test_y.numpy(),
        obs=FLAGS.OBSERVATION_DATE,
        gaussian_std=FLAGS.INFERENCE_GAUSSIAN_STD
    )
    print("Saving inference results...")
    np.save(pjoin(_get_result_path(), f"inference_result_{timestamp}.npy"), y_hat_list)
    print("Saving prediction graph...")
    save_prediction(y_hat_list, test_y.numpy(), f"Prediction {FLAGS.TARGET_WELL}, true model: {FLAGS.TRUE_MODEL}", timestamp)


if __name__ == "__main__":
    main()
# Out:
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_x = torch.tensor(input_train, dtype=torch.float32)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:82: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_y = torch.tensor(targets_train, dtype=torch.float32)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   val_x = torch.tensor(input_val, dtype=torch.float32)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_x = torch.tensor(input_test, dtype=torch.float32)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:86: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_y = torch.tensor(targets_train, dtype=torch.float32)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:87: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   val_y = torch.tensor(targets_val, dtype=torch.float32)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_18986/1539486849.py:88: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_y = torch.tensor(targets_test, dtype=torch.float32)
# Shapes before calling get_model:
# train_x shape: torch.Size([450, 90000])
# train_y shape: torch.Size([450, 4200])
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gaussian_noise (GaussianNo  (None, 90000, 1)          0
#  ise)
#
#  lstm (LSTM)                 (None, 90000, 50)         10400
#
#  dropout (Dropout)           (None, 90000, 50)         0
#
#  lstm_1 (LSTM)               (None, 90000, 50)         20200
#
#  dropout_1 (Dropout)         (None, 90000, 50)         0
#
#  flatten (Flatten)           (None, 4500000)           0
#
#  dense (Dense)               (None, 256)               1152000256
#
#  dense_1 (Dense)             (None, 4200)              1079400
#
# =================================================================
# Total params: 1153110256 (4.30 GB)
# Trainable params: 1153110256 (4.30 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# latest checkpoint: None
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([2, 90000])
# Batch Y shape: torch.Size([2, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])
# Batch X shape: torch.Size([32, 90000])
# Batch Y shape: torch.Size([32, 4200])

# %%
train_indices = range(0, 450)
test_indices = range(450, 475)
val_indices = range(475, 500)

df_input = df_t
df_targets = target_df_t
# processor.remove_zero_wopr(well)

# Convert DataFrames to PyTorch tensors
input_data = torch.tensor(df_input.values, dtype=torch.float32)
targets = torch.tensor(df_targets.values, dtype=torch.float32)

# Split the data into training, testing, and validation sets
input_train, targets_train = input_data[train_indices], targets[train_indices]
input_test, targets_test = input_data[test_indices], targets[test_indices]
input_val, targets_val = input_data[val_indices], targets[val_indices]


# Convert NumPy arrays to PyTorch tensors
train_x = torch.tensor(input_train, dtype=torch.float32)
train_x.shape[2]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming df_input and df_targets are your input and target DataFrames
# Make sure to replace these with your actual data

# Specify the indices for training, testing, and validation
train_indices = range(0, 450)
test_indices = range(450, 475)
val_indices = range(475, 500)

df_input = df_t
df_targets = target_df_t

# Convert DataFrames to PyTorch tensors
input_data = torch.tensor(df_input.values, dtype=torch.float32)
targets = torch.tensor(df_targets.values, dtype=torch.float32)

# Split the data into training, testing, and validation sets
input_train, targets_train = input_data[train_indices], targets[train_indices]
input_test, targets_test = input_data[test_indices], targets[test_indices]
input_val, targets_val = input_data[val_indices], targets[val_indices]

# Define a simple neural network model
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(90000, 256)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(256, 4200)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Instantiate the model, loss function, and optimizer
model = SimpleNN()
criterion = nn.MSELoss()  # Mean Squared Error Loss for regression task
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Convert data to PyTorch DataLoader for batch processing
train_dataset = TensorDataset(input_train, targets_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}")

# Evaluate the model on the validation set
model.eval()
with torch.no_grad():
    val_outputs = model(input_val)
    val_loss = criterion(val_outputs, targets_val)
    print(f"Validation Loss: {val_loss.item()}")
# Out:
# Epoch 1/10, Loss: 11164357.0
# Epoch 2/10, Loss: 7923871.5
# Epoch 3/10, Loss: 1541743.5
# Epoch 4/10, Loss: 12678111.0
# Epoch 5/10, Loss: 5087460.0
# Epoch 6/10, Loss: 9761654.0
# Epoch 7/10, Loss: 4921021.0
# Epoch 8/10, Loss: 6962698.0
# Epoch 9/10, Loss: 8209841.0
# Epoch 10/10, Loss: 1863108.0
# Validation Loss: 8621163.0

# %%
import torch.nn.functional as F
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming df_input and df_targets are your input and target DataFrames
# Make sure to replace these with your actual data

# Specify the indices for training, testing, and validation
train_indices = range(0, 450)
test_indices = range(450, 475)
val_indices = range(475, 500)

df_input = df_t
df_targets = target_df_t

# Convert DataFrames to PyTorch tensors
input_data = torch.tensor(df_input.values, dtype=torch.float32)
targets = torch.tensor(df_targets.values, dtype=torch.float32)

# Split the data into training, testing, and validation sets
input_train, targets_train = input_data[train_indices], targets[train_indices]
input_test, targets_test = input_data[test_indices], targets[test_indices]
input_val, targets_val = input_data[val_indices], targets[val_indices]

class ComplexNN(nn.Module):
    def __init__(self):
        super(ComplexNN, self).__init__()
        self.fc1 = nn.Linear(90000, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 4200)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.batch_norm1 = nn.BatchNorm1d(512)
        self.batch_norm2 = nn.BatchNorm1d(256)
        self.batch_norm3 = nn.BatchNorm1d(128)

    def forward(self, x):
        x = self.fc1(x)
        x = self.batch_norm1(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc2(x)
        x = self.batch_norm2(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc3(x)
        x = self.batch_norm3(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc4(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.fc5(x)
        return x


# Instantiate the model, loss function, and optimizer
model = SimpleNN()
criterion = nn.MSELoss()  # Mean Squared Error Loss for regression task
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Convert data to PyTorch DataLoader for batch processing
train_dataset = TensorDataset(input_train, targets_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}")

# Evaluate the model on the validation set
model.eval()
with torch.no_grad():
    val_outputs = model(input_val)
    val_loss = criterion(val_outputs, targets_val)
    print(f"Validation Loss: {val_loss.item()}")
# Out:
# Epoch 1/10, Loss: 170766.46875
# Epoch 2/10, Loss: 11259673.0
# Epoch 3/10, Loss: 10776707.0
# Epoch 4/10, Loss: 7760842.5
# Epoch 5/10, Loss: 5403753.5
# Epoch 6/10, Loss: 12070947.0
# Epoch 7/10, Loss: 10437511.0
# Epoch 8/10, Loss: 11117633.0
# Epoch 9/10, Loss: 6633403.0
# Epoch 10/10, Loss: 9259043.0
# Validation Loss: 8621116.0

# %%
9259043.0 - 6633403.0
# Out:
# 2625640.0

# %%
import shap
import numpy as np
import torch
from sklearn.ensemble import RandomForestRegressor


train_indices = range(0, 10)
# test_indices = range(450, 475)
# val_indices = range(475, 500)

# df_input = df_t
# df_targets = target_df_t
df_input = df_t.iloc[:50, :]
df_targets = target_df_t.iloc[:50]

# Convert DataFrames to PyTorch tensors
input_data = torch.tensor(df_input.values, dtype=torch.float32)
targets = torch.tensor(df_targets.values, dtype=torch.float32)

# Split the data into training, testing, and validation sets
input_train, targets_train = input_data[train_indices], targets[train_indices]
# input_test, targets_test = input_data[test_indices], targets[test_indices]
# input_val, targets_val = input_data[val_indices], targets[val_indices]

model = RandomForestRegressor()
model.fit(input_train, targets_train)  # Replace df_input and df_targets with your actual training data

# Create a SHAP explainer
explainer = shap.TreeExplainer(model)

# Calculate SHAP values for a sample of your data
sample_idx = 0  # You can choose any index from your dataset
sample = df_input.iloc[sample_idx, :]  # Assuming df_input is your input DataFrame
sample = sample.values.reshape(1, -1)
shap_values = explainer.shap_values(sample)

# Summarize the feature importance
shap.summary_plot(shap_values, df_input)
# Out:
# Creating legend with loc="best" can be slow with large amounts of data.
# Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
# Creating legend with loc="best" can be slow with large amounts of data.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     441     """
#     442     Draw the canvas, then save it using `.image.imsave` (to which
#     443     *pil_kwargs* and *metadata* are forwarded).
#     444     """
# --> 445     FigureCanvasAgg.draw(self)
#     446     mpl.image.imsave(
#     447         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:383, in FigureCanvasAgg.draw(self)
#     381 def draw(self):
#     382     # docstring inherited
# --> 383     self.renderer = self.get_renderer()
#     384     self.renderer.clear()
#     385     # Acquire a lock on the shared font cache.
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:398, in FigureCanvasAgg.get_renderer(self)
#     396 reuse_renderer = (self._lastKey == key)
#     397 if not reuse_renderer:
# --> 398     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     399     self._lastKey = key
#     400 return self.renderer
#
# File ~/code/apps/origenai/venv/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:70, in RendererAgg.__init__(self, width, height, dpi)
#      68 self.width = width
#      69 self.height = height
# ---> 70 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      71 self._filter_renderers = []
#      73 self._update_methods()
#
# ValueError: Image size of 695x110633 pixels is too large. It must be less than 2^16 in each direction.

# %%
shap_values
# Out:
# [array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  array([[0., 0., 0., ..., 0., 0., 0.]]),
#  ...]

# %%
import numpy as np
import random
import time
import qri
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.core import Activation, Dense, Dropout
from keras.models import Sequential
from keras.optimizers import SGD
import sys

# If you want to pass an argument when running the script, uncomment the following lines
# if len(sys.argv) > 1:
#     first = int(sys.argv[1])
# else:
#     first = <your_default_value>

# Model name
MDL_NAME = "fcn-a-3hidden-thick%s" % first  # Assuming 'first' is defined

# Seed random number generator
np.random.seed(42)

# Load your specific data (replace 'your_data.pkl.gz' with the actual file path)
datasets = qri.load_data("your_data.pkl.gz")

# Split into 2D datasets
train_set, valid_set, test_set = datasets

# Build neural network
model = Sequential()
model.add(Dense(48, input_shape=(first,), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(first, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(first, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(12))

# Use stochastic gradient descent and compile the model
sgd = SGD(lr=0.001, momentum=0.99, decay=1e-6, nesterov=True)
model.compile(loss=qri.mae_clip, optimizer=sgd)

# Use early stopping and saving as callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10)
save_best = ModelCheckpoint("models/%s.mdl" % MDL_NAME, save_best_only=True)
callbacks = [early_stop, save_best]

# Train the model
t0 = time.time()
hist = model.fit(train_set[0], train_set[1], validation_data=valid_set,
                 verbose=2, callbacks=callbacks, epochs=1000, batch_size=10)
time_elapsed = time.time() - t0

# Load the best model
model.load_weights("models/%s.mdl" % MDL_NAME)

# Print time elapsed and loss on the testing dataset
test_set_loss = model.evaluate(test_set[0], test_set[1])
print("\nTime elapsed: %f s" % time_elapsed)
print("Testing set loss: %f" % test_set_loss)

# Save results
qri.save_results("results/%s.out" % MDL_NAME, time_elapsed, test_set_loss)
# qri.save_history("models/%s.hist" % MDL_NAME, hist.history)

# Plot training and validation loss
# qri.plot_train_valid_loss(hist.history)

# Make predictions
# qri.plot_test_predictions(model, train_set)

# %%
target_dfs_encoded.shape
# Out:
# (4200, 501)

# %%
dfs_encoded.shape
# Out:
# (90000, 501)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# Assuming df_input and df_targets are your input and target DataFrames
# Make sure to replace these with your actual data

df_input = df_t
df_targets = target_df_t
# label_encoder = LabelEncoder()
# df_encoded['name'] = label_encoder.fit_transform(df_input['name'])

# Convert DataFrames to PyTorch tensors
input_data = torch.tensor(df_input.values, dtype=torch.float32)
targets = torch.tensor(df_targets.values, dtype=torch.float32)

# Split the data into training and validation sets
input_train, input_val, targets_train, targets_val = train_test_split(
    input_data, targets, test_size=0.2, random_state=42
)

# Define a simple neural network model
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(90000, 256)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(256, 4200)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# Instantiate the model, loss function, and optimizer
model = SimpleNN()
criterion = nn.MSELoss()  # Mean Squared Error Loss for regression task
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Convert data to PyTorch DataLoader for batch processing
train_dataset = TensorDataset(input_train, targets_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Train the model
num_epochs = 10
for epoch in range(num_epochs):
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}")

# Evaluate the model on the validation set
model.eval()
with torch.no_grad():
    val_outputs = model(input_val)
    val_loss = criterion(val_outputs, targets_val)
    print(f"Validation Loss: {val_loss.item()}")
# Out:
# Epoch 1/10, Loss: 9803272.0
# Epoch 2/10, Loss: 7832621.5
# Epoch 3/10, Loss: 8496736.0
# Epoch 4/10, Loss: 8261475.0
# Epoch 5/10, Loss: 7251770.0
# Epoch 6/10, Loss: 7898776.0
# Epoch 7/10, Loss: 8564776.0
# Epoch 8/10, Loss: 9317698.0
# Epoch 9/10, Loss: 9487942.0
# Epoch 10/10, Loss: 8700524.0
# Validation Loss: 9418390.0

# %%
num_samples = target_dfs_encoded.shape[0]

# Create a random permutation of indices
np.random.seed(42)

# Randomly sample rows from dfs_encoded and target_dfs_encoded
sampled_dfs = dfs_encoded.sample(n=num_samples, random_state=42)
sampled_target_dfs = target_dfs_encoded.sample(n=num_samples, random_state=42)


lreg = LinearRegression()
rfe = RFE(lreg)
rfe.n_features_to_select = 300  # Replace 10 with the desired number of features
X_rfe = rfe.fit_transform(sampled_dfs, sampled_target_dfs)

X_rfe = rfe.transform(dfs_encoded)
X_target_rfe = rfe.transform(target_dfs_encoded)

# %%
import shap
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# Assume you have a trained model (replace this with your actual model)
model = RandomForestRegressor()

model.fit(sampled_dfs, sampled_target_dfs)

# Create a SHAP explainer
explainer = shap.TreeExplainer(model)

# Calculate SHAP values for a sample of your data
sample_idx = 0  # You can choose any index from your dataset
sample = X_train[sample_idx]
sample = sample.reshape(1, -1)
shap_values = explainer.shap_values(sample)

# Summarize the feature importance
shap.summary_plot(shap_values, X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s2/gm1kddvs2vq0pxwpr1g7n2k00000gn/T/ipykernel_11477/2108174742.py in ?()
#       4
#       5 # Assume you have a trained model (replace this with your actual model)
#       6 model = RandomForestRegressor()
#       7
# ----> 8 model.fit(sampled_dfs, sampled_target_dfs)
#       9
#      10 # Create a SHAP explainer
#      11 explainer = shap.TreeExplainer(model)
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1347                 skip_parameter_validation=(
#    1348                     prefer_skip_nested_validation or global_skip_validation
#    1349                 )
#    1350             ):
# -> 1351                 return fit_method(estimator, *args, **kwargs)
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py in ?(self, X, y, sample_weight)
#     359         # Validate or convert input data
#     360         if issparse(y):
#     361             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     362
# --> 363         X, y = self._validate_data(
#     364             X,
#     365             y,
#     366             multi_output=True,
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1188         raise ValueError(
#    1189             f"{estimator_name} requires y to be passed, but the target y is None"
#    1190         )
#    1191
# -> 1192     X = check_array(
#    1193         X,
#    1194         accept_sparse=accept_sparse,
#    1195         accept_large_sparse=accept_large_sparse,
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     948                         )
#     949                     array = xp.astype(array, dtype, copy=False)
#     950                 else:
#     951                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 952             except ComplexWarning as complex_warning:
#     953                 raise ValueError(
#     954                     "Complex data not supported\n{}\n".format(array)
#     955                 ) from complex_warning
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# ~/code/apps/origenai/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'TRANY'

# %%
import numpy as np
import random
import time
import qri
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.core import Activation, Dense, Dropout
from keras.models import Sequential
from keras.optimizers import SGD
import sys

# If you want to pass an argument when running the script, uncomment the following lines
# if len(sys.argv) > 1:
#     first = int(sys.argv[1])
# else:
#     first = <your_default_value>

# Model name
MDL_NAME = "fcn-a-3hidden-thick%s" % first  # Assuming 'first' is defined

# Seed random number generator
np.random.seed(42)

# Load your specific data (replace 'your_data.pkl.gz' with the actual file path)
datasets = qri.load_data("your_data.pkl.gz")

# Split into 2D datasets
train_set, valid_set, test_set = datasets

# Build neural network
model = Sequential()
model.add(Dense(48, input_shape=(first,), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(first, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(first, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(12))

# Use stochastic gradient descent and compile the model
sgd = SGD(lr=0.001, momentum=0.99, decay=1e-6, nesterov=True)
model.compile(loss=qri.mae_clip, optimizer=sgd)

# Use early stopping and saving as callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=10)
save_best = ModelCheckpoint("models/%s.mdl" % MDL_NAME, save_best_only=True)
callbacks = [early_stop, save_best]

# Train the model
t0 = time.time()
hist = model.fit(train_set[0], train_set[1], validation_data=valid_set,
                 verbose=2, callbacks=callbacks, epochs=1000, batch_size=10)
time_elapsed = time.time() - t0

# Load the best model
model.load_weights("models/%s.mdl" % MDL_NAME)

# Print time elapsed and loss on the testing dataset
test_set_loss = model.evaluate(test_set[0], test_set[1])
print("\nTime elapsed: %f s" % time_elapsed)
print("Testing set loss: %f" % test_set_loss)

# Save results
qri.save_results("results/%s.out" % MDL_NAME, time_elapsed, test_set_loss)
# qri.save_history("models/%s.hist" % MDL_NAME, hist.history)

# Plot training and validation loss
# qri.plot_train_valid_loss(hist.history)

# Make predictions
# qri.plot_test_predictions(model, train_set)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 4
#       2 import random
#       3 import time
# ----> 4 import qri
#       5 from keras.callbacks import EarlyStopping, ModelCheckpoint
#       6 from keras.layers.core import Activation, Dense, Dropout
#
# ModuleNotFoundError: No module named 'qri'

# %%
mydict = {
    "hello": "world",
    1: 2
}

# %%
mydict
# Out:
# {'hello': 'world', 1: 2}

# %%
mydict.keys()
# Out:
# dict_keys(['hello', 1])

# %%
mydict.values()
# Out:
# dict_values(['world', 2])

# %%
for k, v in mydict.items():
    print("key: %s, value: %s" % (k, v))
# Out:
# key: hello, value: world
# key: 1, value: 2
